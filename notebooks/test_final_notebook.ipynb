# %%
from final.model import IDCardProcessor
import matplotlib.pyplot as plt
import cv2

# %%
model = IDCardProcessor()

# %%
results={}
results = model.process_folder(r"D:\ocr_project\exp" , visualize=True)

# %%
for name , data in results.items():
    print(name , data["result"])
# Out:
# augmented_1_egypt_id_1.png {'religion': 'مسلمة', 'marital status': 'أرملة', 'gender': 'أنثى'}
# augmented_1_egypt_id_11 (1).png {'marital status': 'متزوج', 'religion': 'مسيحي', 'gender': 'ذكر'}
# egypt_id_4ن (1).png {'religion': 'مسلمة', 'marital status': 'متزوجة', 'gender': 'أنثى'}

# %%
for name , data in results.items():
    cv2.imshow(name , data["image"])
    cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img ,res=model.process_id_card("../exp/egypt_id_4ن (1).png",visualize=True)
print(res)
plt.imshow(img)
plt.axis("off")
plt.show()
# Out:
# {'religion': 'مسلمة', 'marital status': 'متزوجة', 'gender': 'أنثى'}
